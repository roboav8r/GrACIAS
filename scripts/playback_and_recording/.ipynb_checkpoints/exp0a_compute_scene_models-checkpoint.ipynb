# %%
#!/usr/bin/env python3

# Imports
import os
import time
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import rosbag2_py
from rclpy.serialization import deserialize_message
from rosidl_runtime_py.utilities import get_message

import rclpy
from rclpy.node import Node

from situated_hri_interfaces.srv import SceneVisRec, SceneAudioRec

from PIL import Image as PILImage
import cv2
import cv_bridge

import torch, clip

# Parameters
filepath = '../../bags/e1_est_tuning'
actual_scene_labels = ['campus','courtyard','lab','lobby']
cpjku_audio_scene_labels = ['airport', 'bus', 'metro', 'metro_station', 'park', 'public_square', 'shopping_mall', 'street_pedestrian', 'street_traffic', 'tram']

# Helper functions
def typename(topic_name, topic_types):
    for topic_type in topic_types:
        if topic_type.name == topic_name:
            return topic_type.type
    raise ValueError(f"topic {topic_name} not in bag")

# ROS members
rclpy.init()
node = Node('compute_obs_models_node')
audio_scene_rec_client = node.create_client(SceneAudioRec, 'scene_audio_rec_service')

# Initialize observation models and time array
cpjku_audio_scene_model = np.zeros((len(actual_scene_labels),len(cpjku_audio_scene_labels)))
cpjku_inference_times = []

### COMPUTE AUDIO SCENE RECOGNITION MODEL
# Traverse filepath
for root, dirs, files in os.walk(filepath):

    # Examine each file
    for file in files:
        
        # If it is an mcap, examine
        if os.path.splitext(file)[-1] == '.mcap':

            # Get labels based on filepath
            labels = os.path.normpath(root).split(os.sep)
            command_actual = labels[-1]
            modality_actual = labels[-2]
            role_actual = labels[-3]
            scene_actual = labels[-4]

            scene_actual_idx = actual_scene_labels.index(scene_actual)
            
            reader = rosbag2_py.SequentialReader()            
            reader.open(
                rosbag2_py.StorageOptions(uri=os.path.join(root,file), storage_id="mcap"),
                rosbag2_py.ConverterOptions(
                    input_serialization_format="cdr", output_serialization_format="cdr"
                ),
            )
            topic_types = reader.get_all_topics_and_types()

            # Iterate through messages
            while reader.has_next():
                topic, data, timestamp = reader.read_next()
                msg_type = get_message(typename(topic,topic_types))

                # Handle audio scene data
                if topic=='/audio_data':
                    audio_scene_req = SceneAudioRec.Request()
                    audio_scene_req.scene_audio = deserialize_message(data,msg_type)
                    future = audio_scene_rec_client.call_async(audio_scene_req)
                    rclpy.spin_until_future_complete(node, future)
                    
                    est_scene_idx = np.argmax(future.result().scene_class.probabilities)
                    
                    cpjku_audio_scene_model[scene_actual_idx,est_scene_idx] += 1
                    cpjku_inference_times.append(future.result().inference_time)
                
            del reader

# Save pandas df to csv
scene_labels = ['campus','courtyard','lab','lobby']
audio_obs_labels = ['airport', 'bus', 'metro', 'metro_station', 'park', 'public_square', 'shopping_mall', 'street_pedestrian', 'street_traffic', 'tram']

audio_model_df = pd.DataFrame(cpjku_audio_scene_model,columns=audio_obs_labels,index=scene_labels)
audio_model_df.to_csv("../../results/exp0_obs_models/cpjku_audio_scene_obs_model_raw.csv")

# Smooth the model
smoothed_audio_model = cpjku_audio_scene_model + 1
smoothed_audio_model_df = pd.DataFrame(smoothed_audio_model,columns=audio_obs_labels,index=scene_labels)
smoothed_audio_model_df.to_csv("../../results/exp0_obs_models/cpjku_audio_scene_obs_model_smoothed.csv")

# Normalize the smoothed model
normalized_audio_model = smoothed_audio_model / smoothed_audio_model.sum(axis=1)[:,np.newaxis]
normalized_audio_model_df = pd.DataFrame(normalized_audio_model,columns=audio_obs_labels,index=scene_labels)
normalized_audio_model_df.to_csv("../../results/exp0_obs_models/cpjku_audio_scene_obs_model_normalized.csv")

# Cleanup
rclpy.shutdown()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 77
#      74 topic_types = reader.get_all_topics_and_types()
#      76 # Iterate through messages
# ---> 77 while reader.has_next():
#      78     topic, data, timestamp = reader.read_next()
#      79     msg_type = get_message(typename(topic,topic_types))
#
# KeyboardInterrupt:

# %%
#

# %%
# CLIP model from the top

# Imports
import os
import time
import json

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import rosbag2_py
from rclpy.serialization import deserialize_message
from rosidl_runtime_py.utilities import get_message

import rclpy
from rclpy.node import Node

from situated_hri_interfaces.srv import SceneVisRec, SceneAudioRec

from PIL import Image as PILImage
import cv2
import cv_bridge

import torch, clip

# Parameters
filepath = '../../bags/e1_est_tuning'
actual_scene_labels = ['campus','courtyard','lab','lobby']
cpjku_audio_scene_labels = ['airport', 'bus', 'metro', 'metro_station', 'park', 'public_square', 'shopping_mall', 'street_pedestrian', 'street_traffic', 'tram']

# Helper functions
def typename(topic_name, topic_types):
    for topic_type in topic_types:
        if topic_type.name == topic_name:
            return topic_type.type
    raise ValueError(f"topic {topic_name} not in bag")

# ROS members
rclpy.init()
node = Node('compute_obs_models_node')
audio_scene_rec_client = node.create_client(SceneAudioRec, 'scene_audio_rec_service')

bridge = cv_bridge.CvBridge()
nn_img_size = 416

# CLIP
clip_device = "cuda" if torch.cuda.is_available() else "cpu"
clip_models = ['RN50','ViT-B/32','ViT-L/14']
# available: ['RN50', 'RN101','RN50x4','RN50x16','RN50x64','ViT-B/32','ViT-B/16','ViT-L/14','ViT-L/14@336px']

# text descriptions
scene_descriptions = {'basic_description': ['college campus','a courtyard','a lab', 'a lobby'],
                     'social_in_out_desc': ['a picture of a public outdoor area with high social activity','a picture of a private outdoor area with low social activity','a picture of a private indoor area with low social activity','a picture of a public indoor area with high social activity']}

clip_scene_results = dict()

for model in clip_models:
    clip_model, clip_preprocess = clip.load(model, device=clip_device)

    for desc_name in scene_descriptions.keys():

        # Compute text features
        desc_text = scene_descriptions[desc_name]
        text_tokens = clip.tokenize(desc_text).to(clip_device)
        text_features = clip_model.encode_text(text_tokens)

        # Reset observation model
        clip_scene_obs_model = np.zeros((len(actual_scene_labels),len(desc_text)))
        clip_scene_inference_times = []

        # Traverse filepath
        for root, _, files in os.walk(filepath):
        
            # Examine each file
            for file in files:
                
                # If it is an mcap, examine
                if os.path.splitext(file)[-1] == '.mcap':
        
                    # Get labels based on filepath
                    labels = os.path.normpath(root).split(os.sep)
                    command_actual = labels[-1]
                    cmd_mode_actual = labels[-2]
                    role_actual = labels[-3]
                    scene_actual = labels[-4]
                    iteration = os.path.splitext(file)[-2].split('_')[-1]
        
                    scene_actual_idx = actual_scene_labels.index(scene_actual)
                    
                    # Create reader object           
                    reader = rosbag2_py.SequentialReader()            
                    reader.open(
                        rosbag2_py.StorageOptions(uri=os.path.join(root,file), storage_id="mcap"),
                        rosbag2_py.ConverterOptions(
                            input_serialization_format="cdr", output_serialization_format="cdr"
                        ),
                    )
                    topic_types = reader.get_all_topics_and_types()
        
                    # Iterate through messages
                    img_received = False
                    while reader.has_next():
                        topic, data, timestamp = reader.read_next()
                        msg_type = get_message(typename(topic,topic_types))
        
                        if topic=='/oak/rgb/image_raw':
                            latest_img_msg = deserialize_message(data,msg_type)
                            
                            start_time = time.time() # start clock
                            
                            cv_image = bridge.imgmsg_to_cv2(latest_img_msg, desired_encoding='rgb8')

                            # CLIP recognition
                            pil_image = PILImage.fromarray(cv_image)
                            clip_image = clip_preprocess(pil_image).unsqueeze(0).to(clip_device)
                            image_features = clip_model.encode_image(clip_image)

                            logits_per_image, _ = clip_model(clip_image, text_tokens)
                            scene_probs = logits_per_image.softmax(dim=-1).detach().cpu().numpy()[0]

                            clip_scene_obs_model[scene_actual_idx, np.argmax(scene_probs)] +=1
                            clip_scene_inference_times.append(time.time() - start_time)
                        
                    del reader
                    
        # Save model to results dict
        key_name = "%s_%s" % (model, desc_name)
        clip_scene_results[key_name] = dict()
        clip_scene_results[key_name]['model'] = clip_scene_obs_model
        clip_scene_results[key_name]['times'] = clip_scene_inference_times
# Out:
# /home/jd/mambaforge/envs/sit_int/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1695392020201/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# [WARN] [1725993383.028821232] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993383.362715119] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993383.708140411] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993383.989500419] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993384.350250609] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993385.165797151] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993385.900778050] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993386.624523825] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993387.315974458] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993407.675684294] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993409.480154397] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993411.016107014] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993412.720492296] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993414.331397570] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993420.645776608] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993436.248907146] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993438.432120072] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993440.569280691] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993442.926087309] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993445.120644166] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993447.031671076] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993448.461082279] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993449.701257077] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993451.105259284] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993452.280439576] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993729.902673099] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993733.680877384] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993737.512095534] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993741.342153209] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993744.592330017] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993748.689571781] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993752.265118687] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993756.118420327] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993760.053436853] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993763.489033973] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993781.351339367] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993786.741071288] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993789.808819841] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993793.459782965] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993797.126398222] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993800.426954793] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993802.975366915] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993807.205445482] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993810.858477912] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993814.994793147] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993818.987658871] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993824.435907751] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993827.917507941] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993831.071704671] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993834.699047631] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993838.382740936] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993840.538740907] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993844.364582271] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1725993847.875888241] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [
[rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031183.600418570] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031188.723051315] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031193.155193599] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031197.954024621] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031202.527351529] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031206.726561254] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031231.545826172] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031238.197815878] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031241.679674114] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031245.769897358] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031249.959009258] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031253.742528681] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031256.798181844] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031262.179660003] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031266.858967477] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031272.055317406] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031277.125040942] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031283.793364120] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031287.407812992] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031290.683533111] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031294.666044746] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031298.548059143] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031300.814553511] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031305.257459643] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031309.357595182] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031313.845066004] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726031318.049905190] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032848.094031685] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032849.958645888] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032852.571653218] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032854.150016882] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032914.961107272] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032915.481641031] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032916.072582373] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032916.911971581] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order
# [WARN] [1726032917.239564957] [rosbag2_storage_mcap]: no message indices found, falling back to reading in file order

# %%
for key in clip_scene_results.keys():

    # Remove / to avoid path errors
    key_path = key.replace("/","")
    
    # Save times to json file
    with open("../../results/exp0_obs_models/" + key_path + "_inference_times.json","w") as outfile:
        outfile.write(json.dumps(clip_scene_results[key]['times']))

    # Save models to csv files
    scene_labels = ['campus_actual','courtyard_actual','lab_actual','lobby_actual']
    clip_obs_labels = ['campus_est','courtyard_est','lab_est','lobby_est']

    clip_model_df = pd.DataFrame(clip_scene_results[key]['model'],columns=clip_obs_labels,index=scene_labels)
    clip_model_df.to_csv("../../results/exp0_obs_models/" + key_path + "_scene_obs_model_raw.csv")
    
    # Smooth the model
    smoothed_clip_model = clip_model_df + 1
    smoothed_clip_model_df = pd.DataFrame(smoothed_clip_model,columns=clip_obs_labels,index=scene_labels)
    smoothed_clip_model_df.to_csv("../../results/exp0_obs_models/" + key_path + "_scene_obs_model_smoothed.csv")
    
    # Normalize the smoothed model
    norm_vector = np.expand_dims(smoothed_clip_model.sum(axis=1),axis=1)
    
    normalized_clip_model = smoothed_clip_model / norm_vector
    normalized_clip_model_df = pd.DataFrame(normalized_clip_model,columns=clip_obs_labels,index=scene_labels)
    normalized_clip_model_df.to_csv("../../results/exp0_obs_models/" + key_path + "_scene_obs_model_normalized.csv")

# %%
# Save clip scene obs model to file
for key in clip_scene_results.keys():
    clip_scene_results[key]['model'] = clip_scene_results[key]['model'].tolist()

with open("../../results/exp0_obs_models/clip_scene_obs_model.json","w") as outfile:
    outfile.write(json.dumps(clip_scene_results,indent=4))

# %%
clip_scene_obs_model_dict = json.load(open('../../results/exp0_obs_models/clip_scene_obs_model.json'))

clip_obs_results_df = pd.DataFrame(np.zeros((6,9)),index=clip_scene_obs_model_dict.keys(),columns=['acc','p_campus','r_campus','p_crtyrd','r_crtyrd','p_lab','r_lab','p_lobby','r_lobby'])

# %%
row_labels = ['campus_actual','courtyard_actual','lab_actual','lobby_actual']
col_labels = ['campus_est','courtyard_est','lab_est','lobby_est']

for clip_cfg in clip_scene_obs_model_dict.keys():
    print(clip_cfg)
    model_df = pd.DataFrame(clip_scene_obs_model_dict[clip_cfg]['model'], index=row_labels, columns=col_labels)
    print(model_df)
